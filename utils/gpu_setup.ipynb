# %%
# install uv
# !pip install uv
# Out:
# ...
#    ---------------------------------------- 0.0/18.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/18.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/18.5 MB 435.7 kB/s eta 0:00:43
#    ---------------------------------------- 0.1/18.5 MB 1.2 MB/s eta 0:00:16
#    - -------------------------------------- 0.7/18.5 MB 4.7 MB/s eta 0:00:04
#    - -------------------------------------- 0.8/18.5 MB 5.4 MB/s eta 0:00:04
#    -- ------------------------------------- 1.1/18.5 MB 4.6 MB/s eta 0:00:04
#    --- ------------------------------------ 1.5/18.5 MB 5.2 MB/s eta 0:00:04
#    ---- ----------------------------------- 2.0/18.5 MB 6.2 MB/s eta 0:00:03
#    ----- ---------------------------------- 2.5/18.5 MB 6.6 MB/s eta 0:00:03
#    ------ --------------------------------- 3.2/18.5 MB 7.6 MB/s eta 0:00:02
#    ------- -------------------------------- 3.6/18.5 MB 7.6 MB/s eta 0:00:02
# ...

# %%
# !pip install -r ../requirements.txt
# Out:
# ...
#      ---------------------------------------- 0.0/61.0 kB ? eta -:--:--
#      ------------ ------------------------- 20.5/61.0 kB 640.0 kB/s eta 0:00:01
#      ------------------------------- ------ 51.2/61.0 kB 871.5 kB/s eta 0:00:01
#      ------------------------------- ------ 51.2/61.0 kB 871.5 kB/s eta 0:00:01
#      -------------------------------------- 61.0/61.0 kB 360.3 kB/s eta 0:00:00
# ...
#      ---------------------------------------- 0.0/87.2 kB ? eta -:--:--
#      ------------------------------------- -- 81.9/87.2 kB 4.8 MB/s eta 0:00:01
#      -------------------------------------- 87.2/87.2 kB 986.5 kB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...

# %%
import torch

# %%
# test gpu device is loaded
torch.cuda.is_available()
# Out:
# False

# %%
torch.cuda.device_count()
# Out:
# 0

# %%
torch.cuda.current_device()
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 torch.cuda.current_device()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\cuda\__init__.py:1026, in current_device()
#    1024 def current_device() -> int:
#    1025     r"""Return the index of a currently selected device."""
# -> 1026     _lazy_init()
#    1027     return torch._C._cuda_getDevice()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\cuda\__init__.py:363, in _lazy_init()
#     358     raise RuntimeError(
#     359         "Cannot re-initialize CUDA in forked subprocess. To use CUDA with "
#     360         "multiprocessing, you must use the 'spawn' start method"
#     361     )
# ...

# %%
torch.cuda.device(0)

# %%
torch.cuda.get_device_name(0)
